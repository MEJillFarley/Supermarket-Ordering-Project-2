# %%
import pandas as pd
import datetime
import numpy as np

# %%
#import csv files
invoice_df = pd.read_csv("Data_Folder/Invoices.csv")
order_leads_df = pd.read_csv("Data_Folder/OrderLeads.csv")
sales_df = pd.read_csv("Data_Folder/SalesTeam.csv")

# %%
#display invoice and order_leads dataframes
invoice_df.head()
# Out:
#            Order Id        Date           Meal Id        Company Id  \
# 0  839FKFW2LLX4LMBB  27-05-2016  INBUX904GIHI8YBD  LJKS5NK6788CYMUU
# 1  97OX39BGVMHODLJM  27-09-2018  J0MMOOPP709DIDIE  LJKS5NK6788CYMUU
# 2  041ORQM5OIHTIU6L  24-08-2014  E4UJLQNCI16UX5CS  LJKS5NK6788CYMUU
# 3  YT796QI18WNGZ7ZJ  12-04-2014  C9SDFHF7553BE247  LJKS5NK6788CYMUU
# 4  6YLROQT27B6HRF4E  28-07-2015  48EQXS6IHYNZDDZ5  LJKS5NK6788CYMUU
#
#                 Date of Meal                       Participants  Meal Price  \
# 0  2016-05-31 07:00:00+02:00                   ['David Bishop']         469
# 1  2018-10-01 20:00:00+02:00                   ['David Bishop']          22
# 2  2014-08-23 14:00:00+02:00                 ['Karen Stansell']         314
# 3  2014-04-07 21:00:00+02:00                   ['Addie Patino']         438
# 4  2015-07-27 14:00:00+02:00  ['Addie Patino' 'Susan Guerrero']         690
#
#   Type of Meal
# 0    Breakfast
# 1       Dinner
# 2        Lunch
# 3       Dinner
# 4        Lunch

# %%
order_leads_df.head()
# Out:
#            Order Id        Company Id            Company Name        Date  \
# 0  80EYLOKP9E762WKG  LJKS5NK6788CYMUU  Chimera-Chasing Casbah  18-02-2017
# 1  TLEXR1HZWTUTBHPB  LJKS5NK6788CYMUU  Chimera-Chasing Casbah  30-07-2015
# 2  839FKFW2LLX4LMBB  LJKS5NK6788CYMUU  Chimera-Chasing Casbah  27-05-2016
# 3  97OX39BGVMHODLJM  LJKS5NK6788CYMUU  Chimera-Chasing Casbah  27-09-2018
# 4  5T4LGH4XGBWOD49Z  LJKS5NK6788CYMUU  Chimera-Chasing Casbah  14-01-2016
#
#    Order Value  Converted
# 0         4875          1
# 1         8425          0
# 2         4837          0
# 3          343          0
# 4          983          0

# %%
order_leads_df.isnull().sum()
# Out:
# Order Id        0
# Company Id      0
# Company Name    0
# Date            0
# Order Value     0
# Converted       0
# dtype: int64

# %%
#split date into a separate year and month column 
order_leads_df["Year"] = order_leads_df["Date"].str.split('-', expand = True)[2]
order_leads_df["Month"] = order_leads_df["Date"].str.split('-', expand = True)[1]
order_leads_df.head()
# Out:
#            Order Id        Company Id            Company Name        Date  \
# 0  80EYLOKP9E762WKG  LJKS5NK6788CYMUU  Chimera-Chasing Casbah  18-02-2017
# 1  TLEXR1HZWTUTBHPB  LJKS5NK6788CYMUU  Chimera-Chasing Casbah  30-07-2015
# 2  839FKFW2LLX4LMBB  LJKS5NK6788CYMUU  Chimera-Chasing Casbah  27-05-2016
# 3  97OX39BGVMHODLJM  LJKS5NK6788CYMUU  Chimera-Chasing Casbah  27-09-2018
# 4  5T4LGH4XGBWOD49Z  LJKS5NK6788CYMUU  Chimera-Chasing Casbah  14-01-2016
#
#    Order Value  Converted  Year Month
# 0         4875          1  2017    02
# 1         8425          0  2015    07
# 2         4837          0  2016    05
# 3          343          0  2018    09
# 4          983          0  2016    01

# %%
#convert months columns from month number to month name
month_dict = {"01" : 'January', "02" : 'February',
            "03" : 'March', "04": 'April', "05": 'May',
            "06": 'June', "07": 'July', "08": 'August',
            "09": 'September', "10": 'October', "11": 'November', "12": 'December'}
clean_df = order_leads_df.replace({"Month": month_dict})
clean_df.head()
# Out:
#            Order Id        Company Id            Company Name        Date  \
# 0  80EYLOKP9E762WKG  LJKS5NK6788CYMUU  Chimera-Chasing Casbah  18-02-2017
# 1  TLEXR1HZWTUTBHPB  LJKS5NK6788CYMUU  Chimera-Chasing Casbah  30-07-2015
# 2  839FKFW2LLX4LMBB  LJKS5NK6788CYMUU  Chimera-Chasing Casbah  27-05-2016
# 3  97OX39BGVMHODLJM  LJKS5NK6788CYMUU  Chimera-Chasing Casbah  27-09-2018
# 4  5T4LGH4XGBWOD49Z  LJKS5NK6788CYMUU  Chimera-Chasing Casbah  14-01-2016
#
#    Order Value  Converted  Year      Month
# 0         4875          1  2017   February
# 1         8425          0  2015       July
# 2         4837          0  2016        May
# 3          343          0  2018  September
# 4          983          0  2016    January

# %%
#groupby year, month, and sum converted orders
year_month_df = (clean_df.groupby(["Year", "Month"])["Converted"].sum())/(clean_df.groupby(["Year", "Month"])["Converted"].count())

new_df = pd.DataFrame([year_month_df])
year_month_clean = new_df.T
year_month_clean.to_csv("Data_Folder/Year_Month_Converted")

#rename converted column to conversion rate
# company_name_df_clean1 = company_name_df_clean.rename(columns = {"Converted" : "Conversion Rate"})
# company_name_df_clean1.head()

# %%
name_df = clean_df.groupby(["Company Name"])["Converted"].count()
name_df.head()
# Out:
# Company Name
# '48 Wills            13
# 10-Day Causes        18
# 10-Hour Leak         18
# 10-Year $2.30/Mbf    26
# 10-Year-Old Alba     19
# Name: Converted, dtype: int64

# %%
sales_df.head()
# Out:
#            Sales Rep      Sales Rep Id                    Company Name  \
# 0  Jessie Mcallister  97UNNAT790E0WM4N          Chimera-Chasing Casbah
# 1  Jessie Mcallister  97UNNAT790E0WM4N                Tangential Sheds
# 2  Jessie Mcallister  97UNNAT790E0WM4N                   Two-Mile Grab
# 3  Jessie Mcallister  97UNNAT790E0WM4N  Three-Men-And-A-Helper Congo'S
# 4  Jessie Mcallister  97UNNAT790E0WM4N        Biophysical Battleground
#
#          Company Id
# 0  LJKS5NK6788CYMUU
# 1  36MFTZOYMTAJP1RK
# 2  H3JRC7XX7WJAD4ZO
# 3  HB25MDZR0MGCQUGX
# 4  7RVA8TIVBLBXMNO4

# %%
#merge dataframes on OrderID and display new dataframe
#call out in readme that we have a bunch of null values
merged_df = pd.merge(order_leads_df, invoice_df, on = (["Order Id", "Date", "Company Id"]), how = "left")
merged_df.head()
# Out:
#            Order Id        Company Id            Company Name        Date  \
# 0  80EYLOKP9E762WKG  LJKS5NK6788CYMUU  Chimera-Chasing Casbah  18-02-2017
# 1  TLEXR1HZWTUTBHPB  LJKS5NK6788CYMUU  Chimera-Chasing Casbah  30-07-2015
# 2  839FKFW2LLX4LMBB  LJKS5NK6788CYMUU  Chimera-Chasing Casbah  27-05-2016
# 3  97OX39BGVMHODLJM  LJKS5NK6788CYMUU  Chimera-Chasing Casbah  27-09-2018
# 4  5T4LGH4XGBWOD49Z  LJKS5NK6788CYMUU  Chimera-Chasing Casbah  14-01-2016
#
#    Order Value  Converted  Year Month           Meal Id  \
# 0         4875          1  2017    02               NaN
# 1         8425          0  2015    07               NaN
# 2         4837          0  2016    05  INBUX904GIHI8YBD
# 3          343          0  2018    09  J0MMOOPP709DIDIE
# 4          983          0  2016    01               NaN
#
#                 Date of Meal      Participants  Meal Price Type of Meal
# 0                        NaN               NaN         NaN          NaN
# 1                        NaN               NaN         NaN          NaN
# 2  2016-05-31 07:00:00+02:00  ['David Bishop']       469.0    Breakfast
# 3  2018-10-01 20:00:00+02:00  ['David Bishop']        22.0       Dinner
# 4                        NaN               NaN         NaN          NaN

# %%
invoice_df["Year"] = invoice_df["Date"].str.split('-', expand = True)[2]
invoice_df["Month"] = invoice_df["Date"].str.split('-', expand = True)[1]
invoice_df.head()
# Out:
#            Order Id        Date           Meal Id        Company Id  \
# 0  839FKFW2LLX4LMBB  27-05-2016  INBUX904GIHI8YBD  LJKS5NK6788CYMUU
# 1  97OX39BGVMHODLJM  27-09-2018  J0MMOOPP709DIDIE  LJKS5NK6788CYMUU
# 2  041ORQM5OIHTIU6L  24-08-2014  E4UJLQNCI16UX5CS  LJKS5NK6788CYMUU
# 3  YT796QI18WNGZ7ZJ  12-04-2014  C9SDFHF7553BE247  LJKS5NK6788CYMUU
# 4  6YLROQT27B6HRF4E  28-07-2015  48EQXS6IHYNZDDZ5  LJKS5NK6788CYMUU
#
#                 Date of Meal                       Participants  Meal Price  \
# 0  2016-05-31 07:00:00+02:00                   ['David Bishop']         469
# 1  2018-10-01 20:00:00+02:00                   ['David Bishop']          22
# 2  2014-08-23 14:00:00+02:00                 ['Karen Stansell']         314
# 3  2014-04-07 21:00:00+02:00                   ['Addie Patino']         438
# 4  2015-07-27 14:00:00+02:00  ['Addie Patino' 'Susan Guerrero']         690
#
#   Type of Meal  Year Month
# 0    Breakfast  2016    05
# 1       Dinner  2018    09
# 2        Lunch  2014    08
# 3       Dinner  2014    04
# 4        Lunch  2015    07

# %%
invoice_clean_df = invoice_df.replace({"Month": month_dict})
invoice_clean_df.head()
# Out:
#            Order Id        Date           Meal Id        Company Id  \
# 0  839FKFW2LLX4LMBB  27-05-2016  INBUX904GIHI8YBD  LJKS5NK6788CYMUU
# 1  97OX39BGVMHODLJM  27-09-2018  J0MMOOPP709DIDIE  LJKS5NK6788CYMUU
# 2  041ORQM5OIHTIU6L  24-08-2014  E4UJLQNCI16UX5CS  LJKS5NK6788CYMUU
# 3  YT796QI18WNGZ7ZJ  12-04-2014  C9SDFHF7553BE247  LJKS5NK6788CYMUU
# 4  6YLROQT27B6HRF4E  28-07-2015  48EQXS6IHYNZDDZ5  LJKS5NK6788CYMUU
#
#                 Date of Meal                       Participants  Meal Price  \
# 0  2016-05-31 07:00:00+02:00                   ['David Bishop']         469
# 1  2018-10-01 20:00:00+02:00                   ['David Bishop']          22
# 2  2014-08-23 14:00:00+02:00                 ['Karen Stansell']         314
# 3  2014-04-07 21:00:00+02:00                   ['Addie Patino']         438
# 4  2015-07-27 14:00:00+02:00  ['Addie Patino' 'Susan Guerrero']         690
#
#   Type of Meal  Year      Month
# 0    Breakfast  2016        May
# 1       Dinner  2018  September
# 2        Lunch  2014     August
# 3       Dinner  2014      April
# 4        Lunch  2015       July

# %%
#groupby year, month, and sum converted orders
invoice_year_month_df = invoice_clean_df.groupby(["Year", "Month", "Type of Meal"])["Meal Price"].count()
invoice_new_df = pd.DataFrame([invoice_year_month_df])
invoice_year_month_count = invoice_new_df.T
invoice_year_month_count.rename(columns={"Meal Price": "Count of Meal Types"})
# Out:
#                              Count of Meal Types
# Year Month     Type of Meal
# 2014 April     Breakfast                     289
#                Dinner                        269
#                Lunch                         262
#      August    Breakfast                     281
#                Dinner                        307
# ...                                          ...
# 2018 October   Dinner                        297
#                Lunch                         299
#      September Breakfast                     286
#                Dinner                        285
#                Lunch                         255
#
# [180 rows x 1 columns]
